# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/Banane01/robotic-grasping.git
# Out:
# Cloning into 'robotic-grasping'...
# remote: Enumerating objects: 719, done.
# remote: Counting objects: 100% (246/246), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 719 (delta 190), reused 182 (delta 170), pack-reused 473
# Receiving objects: 100% (719/719), 79.57 MiB | 28.62 MiB/s, done.
# Resolving deltas: 100% (428/428), done.

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.11.0-0/Mambaforge-23.11.0-0-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:12
# 🔁 Restarting kernel...

# %%
# !conda create -n robot python=3.9
# !conda activate robot
# !conda install pytorch==1.12.0 torchvision==0.13 cudatoolkit=11.3 -c pytorch -y
# !cd robotic-grasping
# !pip install -r requirements.txt
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/robot
#
#   added / updated specs:
#     - python=3.9
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2024.6.2   |       hbcca054_0         152 KB  conda-forge
#     ld_impl_linux-64-2.40      |       hf3520f5_7         691 KB  conda-forge
#     libgcc-ng-13.2.0           |      h77fa898_11         777 KB  conda-forge
#     libgomp-13.2.0             |      h77fa898_11         434 KB  conda-forge
#     libsqlite-3.46.0           |       hde9e2c9_0         845 KB  conda-forge
#     libxcrypt-4.4.36           |       hd590300_1          98 KB  conda-forge
#     libzlib-1.3.1              |       h4ab18f5_1          60 KB  conda-forge
#     ncurses-6.5                |       h59595ed_0         867 KB  conda-forge
#     openssl-3.3.1              |       h4ab18f5_0         2.8 MB  conda-forge
#     pip-24.0                   |     pyhd8ed1ab_0         1.3 MB  conda-forge
#     python-3.9.19              |h0755675_0_cpython        22.7 MB  conda-forge
#     setuptools-70.1.0          |     pyhd8ed1ab_0         484 KB  conda-forge
#     tzdata-2024a               |       h0c530f3_0         117 KB  conda-forge
#     wheel-0.43.0               |     pyhd8ed1ab_1          57 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        31.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      conda-forge/linux-64::_libgcc_mutex-0.1-conda_forge
#   _openmp_mutex      conda-forge/linux-64::_openmp_mutex-4.5-2_gnu
#   bzip2              conda-forge/linux-64::bzip2-1.0.8-hd590300_5
#   ca-certificates    conda-forge/linux-64::ca-certificates-2024.6.2-hbcca054_0
#   ld_impl_linux-64   conda-forge/linux-64::ld_impl_linux-64-2.40-hf3520f5_7
#   libffi             conda-forge/linux-64::libffi-3.4.2-h7f98852_5
#   libgcc-ng          conda-forge/linux-64::libgcc-ng-13.2.0-h77fa898_11
#   libgomp            conda-forge/linux-64::libgomp-13.2.0-h77fa898_11
#   libnsl             conda-forge/linux-64::libnsl-2.0.1-hd590300_0
#   libsqlite          conda-forge/linux-64::libsqlite-3.46.0-hde9e2c9_0
#   libuuid            conda-forge/linux-64::libuuid-2.38.1-h0b41bf4_0
#   libxcrypt          conda-forge/linux-64::libxcrypt-4.4.36-hd590300_1
#   libzlib            conda-forge/linux-64::libzlib-1.3.1-h4ab18f5_1
#   ncurses            conda-forge/linux-64::ncurses-6.5-h59595ed_0
#   openssl            conda-forge/linux-64::openssl-3.3.1-h4ab18f5_0
#   pip                conda-forge/noarch::pip-24.0-pyhd8ed1ab_0
#   python             conda-forge/linux-64::python-3.9.19-h0755675_0_cpython
#   readline           conda-forge/linux-64::readline-8.2-h8228510_1
#   setuptools         conda-forge/noarch::setuptools-70.1.0-pyhd8ed1ab_0
#   tk                 conda-forge/linux-64::tk-8.6.13-noxft_h4845f30_101
#   tzdata             conda-forge/noarch::tzdata-2024a-h0c530f3_0
#   wheel              conda-forge/noarch::wheel-0.43.0-pyhd8ed1ab_1
#   xz                 conda-forge/linux-64::xz-5.2.6-h166bdaf_0
#
#
#
# Downloading and Extracting Packages:
# python-3.9.19        | 22.7 MB   | :   0% 0/1 [00:00<?, ?it/s]
# openssl-3.3.1        | 2.8 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
# pip-24.0             | 1.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# ncurses-6.5          | 867 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# libsqlite-3.46.0     | 845 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# libgcc-ng-13.2.0     | 777 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# ld_impl_linux-64-2.4 | 691 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# setuptools-70.1.0    | 484 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# libgomp-13.2.0       | 434 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# ca-certificates-2024 | 152 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# tzdata-2024a         | 117 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# libxcrypt-4.4.36     | 98 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# libzlib-1.3.1        | 60 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# wheel-0.43.0         | 57 KB     | :   0% 0/1 [00:00<?, ?it/s]
# python-3.9.19        | 22.7 MB   | :   0% 0.0006883873086152822/1 [00:00<03:53, 234.14s/it]
#
#
# ncurses-6.5          | 867 KB    | :   2% 0.01846157313246156/1 [00:00<00:08,  8.79s/it]
#
# pip-24.0             | 1.3 MB    | :   1% 0.011717545923639992/1 [00:00<00:14, 14.76s/it]
#
#
#
# python-3.9.19        | 22.7 MB   | :  10% 0.09912777244060066/1 [00:00<00:01,  2.15s/it]
#
#
#
#
# libgcc-ng-13.2.0     | 777 KB    | :   2% 0.02058265599678396/1 [00:00<00:13, 14.11s/it]
#
#
#
#
#
# ld_impl_linux-64-2.4 | 691 KB    | :   2% 0.02315425903262003/1 [00:00<00:12, 13.29s/it]
#
#
#
#
#
#
# setuptools-70.1.0    | 484 KB    | :   3% 0.033035521654356984/1 [00:00<00:09,  9.37s/it]
#
#
#
#
#
#
#
# python-3.9.19        | 22.7 MB   | :  19% 0.19206005910366375/1 [00:00<00:01,  1.60s/it]
#
#
#
#
#
#
#
#
# ca-certificates-2024 | 152 KB    | :  11% 0.10500208286602365/1 [00:00<00:03,  3.76s/it]
#
#
#
#
#
#
#
#
#
# tzdata-2024a         | 117 KB    | :  14% 0.13674414722697492/1 [00:00<00:02,  2.95s/it]
#
#
#
#
#
#
#
#
#
#
# libxcrypt-4.4.36     | 98 KB     | :  16% 0.163198629386511/1 [00:00<00:02,  2.51s/it]
#
#
#
#
#
#
#
#
#
#
#
# libzlib-1.3.1        | 60 KB     | :  27% 0.2660863351414558/1 [00:00<00:01,  1.60s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.9.19        | 22.7 MB   | :  47% 0.4742988556359295/1 [00:00<00:00,  1.01it/s]
# openssl-3.3.1        | 2.8 MB    | : 100% 1.0/1 [00:00<00:00,  1.65it/s]
# python-3.9.19        | 22.7 MB   | :  90% 0.902475761594635/1 [00:00<00:00,  1.06it/s]
#
# pip-24.0             | 1.3 MB    | : 100% 1.0/1 [00:01<00:00,  1.21s/it]
#
# pip-24.0             | 1.3 MB    | : 100% 1.0/1 [00:01<00:00,  1.21s/it]
#
#
#
# libsqlite-3.46.0     | 845 KB    | : 100% 1.0/1 [00:01<00:00,  1.24s/it]
#
#
#
# libsqlite-3.46.0     | 845 KB    | : 100% 1.0/1 [00:01<00:00,  1.24s/it]
#
#
#
#
#
#
# setuptools-70.1.0    | 484 KB    | : 100% 1.0/1 [00:01<00:00,  1.53s/it]
#
#
#
#
#
#
# setuptools-70.1.0    | 484 KB    | : 100% 1.0/1 [00:01<00:00,  1.53s/it]
#
#
#
#
# libgcc-ng-13.2.0     | 777 KB    | : 100% 1.0/1 [00:01<00:00,  1.64s/it]
#
#
#
#
# libgcc-ng-13.2.0     | 777 KB    | : 100% 1.0/1 [00:01<00:00,  1.64s/it]
#
#
#
#
#
# ld_impl_linux-64-2.4 | 691 KB    | : 100% 1.0/1 [00:01<00:00,  1.71s/it]
#
#
#
#
#
# ld_impl_linux-64-2.4 | 691 KB    | : 100% 1.0/1 [00:01<00:00,  1.71s/it]
#
#
#
#
#
#
#
# libgomp-13.2.0       | 434 KB    | : 100% 1.0/1 [00:01<00:00,  1.78s/it]
#
#
#
#
#
#
#
# libgomp-13.2.0       | 434 KB    | : 100% 1.0/1 [00:01<00:00,  1.78s/it]
#
#
#
#
#
#
#
#
# ca-certificates-2024 | 152 KB    | : 100% 1.0/1 [00:01<00:00,  1.83s/it]
#
#
#
#
#
#
#
#
# ca-certificates-2024 | 152 KB    | : 100% 1.0/1 [00:01<00:00,  1.83s/it]
#
#
#
#
#
#
#
#
#
# tzdata-2024a         | 117 KB    | : 100% 1.0/1 [00:02<00:00,  2.34s/it]
#
#
#
#
#
#
#
#
#
# tzdata-2024a         | 117 KB    | : 100% 1.0/1 [00:02<00:00,  2.34s/it]
#
#
#
#
#
#
#
#
#
#
# libxcrypt-4.4.36     | 98 KB     | : 100% 1.0/1 [00:02<00:00,  2.40s/it]
#
#
#
#
#
#
#
#
#
#
# libxcrypt-4.4.36     | 98 KB     | : 100% 1.0/1 [00:02<00:00,  2.40s/it]
#
#
#
#
#
#
#
#
#
#
#
# libzlib-1.3.1        | 60 KB     | : 100% 1.0/1 [00:02<00:00,  2.49s/it]
#
#
#
#
#
#
#
#
#
#
#
# libzlib-1.3.1        | 60 KB     | : 100% 1.0/1 [00:02<00:00,  2.49s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# wheel-0.43.0         | 57 KB     | : 100% 1.0/1 [00:02<00:00,  2.55s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# wheel-0.43.0         | 57 KB     | : 100% 1.0/1 [00:02<00:00,  2.55s/it]
#
#
# ncurses-6.5          | 867 KB    | : 100% 1.0/1 [00:02<00:00,  2.61s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate robot
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
# CondaError: Run 'conda init' before 'conda activate'
#
# Channels:
#  - pytorch
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - cudatoolkit=11.3
#     - pytorch==1.12.0
#     - torchvision==0.13
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-4.5          |       2_kmp_llvm           6 KB  conda-forge
#     blas-2.122                 |              mkl          14 KB  conda-forge
#     blas-devel-3.9.0           |   22_linux64_mkl          14 KB  conda-forge
#     certifi-2024.6.2           |     pyhd8ed1ab_0         157 KB  conda-forge
#     cudatoolkit-11.3.1         |      hb98b00a_13       603.5 MB  conda-forge
#     ffmpeg-4.3                 |       hf484d3e_0         9.9 MB  pytorch
#     freetype-2.12.1            |       h267a509_2         620 KB  conda-forge
#     gmp-6.3.0                  |       hac33072_2         449 KB  conda-forge
#     gnutls-3.6.13              |       h85f3911_1         2.0 MB  conda-forge
#     jpeg-9e                    |       h0b41bf4_3         235 KB  conda-forge
#     lame-3.100                 |    h166bdaf_1003         496 KB  conda-forge
#     lcms2-2.15                 |       hfd0df8a_0         235 KB  conda-forge
#     lerc-4.0.0                 |       h27087fc_0         275 KB  conda-forge
#     libblas-3.9.0              |   22_linux64_mkl          15 KB  conda-forge
#     libcblas-3.9.0             |   22_linux64_mkl          14 KB  conda-forge
#     libdeflate-1.17            |       h0b41bf4_0          63 KB  conda-forge
#     libgfortran-ng-13.2.0      |      h69a702a_11          47 KB  conda-forge
#     libgfortran5-13.2.0        |      h3d2ce59_11         1.4 MB  conda-forge
#     libhwloc-2.9.3             |default_h554bfaf_1009         2.5 MB  conda-forge
#     liblapack-3.9.0            |   22_linux64_mkl          14 KB  conda-forge
#     liblapacke-3.9.0           |   22_linux64_mkl          14 KB  conda-forge
#     libpng-1.6.43              |       h2797004_0         281 KB  conda-forge
#     libtiff-4.5.0              |       h6adf6a1_2         397 KB  conda-forge
#     libwebp-base-1.4.0         |       hd590300_0         429 KB  conda-forge
#     libxcb-1.13                |    h7f98852_1004         391 KB  conda-forge
#     llvm-openmp-18.1.4         |       ha31de31_0        57.5 MB  conda-forge
#     mkl-2024.1.0               |     ha957f24_692       121.0 MB  conda-forge
#     mkl-devel-2024.1.0         |     ha770c72_692          34 KB  conda-forge
#     mkl-include-2024.1.0       |     ha957f24_692         673 KB  conda-forge
#     nettle-3.6                 |       he412f7d_0         6.5 MB  conda-forge
#     numpy-2.0.0                |  py310h515e003_0         7.4 MB  conda-forge
#     openh264-2.1.1             |       h780b84a_0         1.5 MB  conda-forge
#     openjpeg-2.5.0             |       hfec8fc6_2         344 KB  conda-forge
#     pillow-9.4.0               |  py310h023d228_1        44.3 MB  conda-forge
#     pthread-stubs-0.4          |    h36c2ea0_1001           5 KB  conda-forge
#     pytorch-1.12.0             |py3.10_cuda11.3_cudnn8.3.2_0        1.19 GB  pytorch
#     pytorch-mutex-1.0          |             cuda           3 KB  pytorch
#     tbb-2021.11.0              |       h00ab1b0_1         191 KB  conda-forge
#     torchvision-0.13.0         |      py310_cu113        28.3 MB  pytorch
#     typing_extensions-4.12.2   |     pyha770c72_0          39 KB  conda-forge
#     xorg-libxau-1.0.11         |       hd590300_0          14 KB  conda-forge
#     xorg-libxdmcp-1.1.3        |       h7f98852_0          19 KB  conda-forge
#     zlib-1.2.13                |       hd590300_5          91 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        2.06 GB
#
# The following NEW packages will be INSTALLED:
#
#   blas               conda-forge/linux-64::blas-2.122-mkl
#   blas-devel         conda-forge/linux-64::blas-devel-3.9.0-22_linux64_mkl
#   cudatoolkit        conda-forge/linux-64::cudatoolkit-11.3.1-hb98b00a_13
#   ffmpeg             pytorch/linux-64::ffmpeg-4.3-hf484d3e_0
#   freetype           conda-forge/linux-64::freetype-2.12.1-h267a509_2
#   gmp                conda-forge/linux-64::gmp-6.3.0-hac33072_2
#   gnutls             conda-forge/linux-64::gnutls-3.6.13-h85f3911_1
#   jpeg               conda-forge/linux-64::jpeg-9e-h0b41bf4_3
#   lame               conda-forge/linux-64::lame-3.100-h166bdaf_1003
#   lcms2              conda-forge/linux-64::lcms2-2.15-hfd0df8a_0
#   lerc               conda-forge/linux-64::lerc-4.0.0-h27087fc_0
#   libblas            conda-forge/linux-64::libblas-3.9.0-22_linux64_mkl
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-22_linux64_mkl
#   libdeflate         conda-forge/linux-64::libdeflate-1.17-h0b41bf4_0
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-13.2.0-h69a702a_11
#   libgfortran5       conda-forge/linux-64::libgfortran5-13.2.0-h3d2ce59_11
#   libhwloc           conda-forge/linux-64::libhwloc-2.9.3-default_h554bfaf_1009
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-22_linux64_mkl
#   liblapacke         conda-forge/linux-64::liblapacke-3.9.0-22_linux64_mkl
#   libpng             conda-forge/linux-64::libpng-1.6.43-h2797004_0
#   libtiff            conda-forge/linux-64::libtiff-4.5.0-h6adf6a1_2
#   libwebp-base       conda-forge/linux-64::libwebp-base-1.4.0-hd590300_0
#   libxcb             conda-forge/linux-64::libxcb-1.13-h7f98852_1004
#   llvm-openmp        conda-forge/linux-64::llvm-openmp-18.1.4-ha31de31_0
#   mkl                conda-forge/linux-64::mkl-2024.1.0-ha957f24_692
#   mkl-devel          conda-forge/linux-64::mkl-devel-2024.1.0-ha770c72_692
#   mkl-include        conda-forge/linux-64::mkl-include-2024.1.0-ha957f24_692
#   nettle             conda-forge/linux-64::nettle-3.6-he412f7d_0
#   numpy              conda-forge/linux-64::numpy-2.0.0-py310h515e003_0
#   openh264           conda-forge/linux-64::openh264-2.1.1-h780b84a_0
#   openjpeg           conda-forge/linux-64::openjpeg-2.5.0-hfec8fc6_2
#   pillow             conda-forge/linux-64::pillow-9.4.0-py310h023d228_1
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-h36c2ea0_1001
#   pytorch            pytorch/linux-64::pytorch-1.12.0-py3.10_cuda11.3_cudnn8.3.2_0
#   pytorch-mutex      pytorch/noarch::pytorch-mutex-1.0-cuda
#   tbb                conda-forge/linux-64::tbb-2021.11.0-h00ab1b0_1
#   torchvision        pytorch/linux-64::torchvision-0.13.0-py310_cu113
#   typing_extensions  conda-forge/noarch::typing_extensions-4.12.2-pyha770c72_0
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.11-hd590300_0
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.3-h7f98852_0
#   zlib               conda-forge/linux-64::zlib-1.2.13-hd590300_5
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2023.11.17-hbcca054_0 --> 2024.6.2-hbcca054_0
#   certifi                           2023.11.17-pyhd8ed1ab_0 --> 2024.6.2-pyhd8ed1ab_0
#   openssl                                  3.2.0-hd590300_1 --> 3.3.1-h4ab18f5_0
#
# The following packages will be DOWNGRADED:
#
#   _openmp_mutex                                   4.5-2_gnu --> 4.5-2_kmp_llvm
#
#
#
# Downloading and Extracting Packages:
# pytorch-1.12.0       | 1.19 GB   | :   0% 0/1 [00:00<?, ?it/s]
# cudatoolkit-11.3.1   | 603.5 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
# mkl-2024.1.0         | 121.0 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
#
# llvm-openmp-18.1.4   | 57.5 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# pillow-9.4.0         | 44.3 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# torchvision-0.13.0   | 28.3 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# ffmpeg-4.3           | 9.9 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# numpy-2.0.0          | 7.4 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# nettle-3.6           | 6.5 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# libhwloc-2.9.3       | 2.5 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# gnutls-3.6.13        | 2.0 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# openh264-2.1.1       | 1.5 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# libgfortran5-13.2.0  | 1.4 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-include-2024.1.0 | 673 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.12.1      | 620 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lame-3.100           | 496 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gmp-6.3.0            | 449 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libwebp-base-1.4.0   | 429 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.5.0        | 397 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# pillow-9.4.0         | 44.3 MB   | :   0% 0.00035265581859715307/1 [00:00<07:28, 448.64s/it]
#
#
# llvm-openmp-18.1.4   | 57.5 MB   | :   0% 0.0002715784169418255/1 [00:00<10:04, 604.56s/it]
#
# pytorch-1.12.0       | 1.19 GB   | :   0% 1.2783531326142215e-05/1 [00:00<4:09:54, 14994.59s/it]
# cudatoolkit-11.3.1   | 603.5 MB  | :   0% 2.5889303500845355e-05/1 [00:00<2:06:25, 7585.93s/it]
#
#
#
# pillow-9.4.0         | 44.3 MB   | :   6% 0.0578355542499331/1 [00:00<00:03,  3.66s/it]
#
#
# llvm-openmp-18.1.4   | 57.5 MB   | :   5% 0.05322936972059779/1 [00:00<00:03,  4.04s/it]
#
# pytorch-1.12.0       | 1.19 GB   | :   0% 0.0021220662001396077/1 [00:00<01:50, 110.74s/it]
# cudatoolkit-11.3.1   | 603.5 MB  | :   0% 0.004142288560135257/1 [00:00<00:57, 57.47s/it]
#
#
#
# pillow-9.4.0         | 44.3 MB   | :  14% 0.14317826235044415/1 [00:00<00:01,  1.97s/it]
#
#
# llvm-openmp-18.1.4   | 57.5 MB   | :  12% 0.12112397395605416/1 [00:00<00:02,  2.39s/it]
#
# mkl-2024.1.0         | 121.0 MB  | :   6% 0.05554648149743131/1 [00:00<00:04,  5.25s/it]
# pytorch-1.12.0       | 1.19 GB   | :   1% 0.0050750619364784595/1 [00:00<01:01, 61.49s/it]
#
#
#
# pillow-9.4.0         | 44.3 MB   | :  22% 0.2232311331719979/1 [00:00<00:01,  1.63s/it]
#
#
# llvm-openmp-18.1.4   | 57.5 MB   | :  20% 0.20178276378777632/1 [00:00<00:01,  1.79s/it]
#
# mkl-2024.1.0         | 121.0 MB  | :   9% 0.09249135058642051/1 [00:00<00:03,  3.93s/it]
# pytorch-1.12.0       | 1.19 GB   | :   1% 0.008091975329448022/1 [00:00<00:47, 47.54s/it]
#
#
#
# pillow-9.4.0         | 44.3 MB   | :  30% 0.3004627574447744/1 [00:00<00:01,  1.50s/it]
#
#
# llvm-openmp-18.1.4   | 57.5 MB   | :  26% 0.2623447507658034/1 [00:00<00:01,  1.76s/it]
#
# mkl-2024.1.0         | 121.0 MB  | :  12% 0.12452746084540416/1 [00:00<00:03,  3.62s/it]
# pytorch-1.12.0       | 1.19 GB   | :   1% 0.011070538128439158/1 [00:00<00:42, 43.21s/it]
#
#
# llvm-openmp-18.1.4   | 57.5 MB   | :  34% 0.34001617801116546/1 [00:00<00:01,  1.57s/it]
#
#
#
# pillow-9.4.0         | 44.3 MB   | :  40% 0.3974431075589915/1 [00:00<00:00,  1.34s/it]
#
# mkl-2024.1.0         | 121.0 MB  | :  16% 0.16134315207044583/1 [00:00<00:02,  3.31s/it]
# pytorch-1.12.0       | 1.19 GB   | :   1% 0.014637143368432836/1 [00:00<00:37, 37.99s/it]
#
# mkl-2024.1.0         | 121.0 MB  | :  19% 0.1928625508736394/1 [00:00<00:02,  3.27s/it]
#
#
#
# pillow-9.4.0         | 44.3 MB   | :  50% 0.4958340809475972/1 [00:00<00:00,  1.25s/it]
#
#
# llvm-openmp-18.1.4   | 57.5 MB   | :  41% 0.4060097333280291/1 [00:00<00:00,  1.66s/it]
# pytorch-1.12.0       | 1.19 GB   | :   2% 0.018127047420469663/1 [00:00<00:33, 34.60s/it]
#
# mkl-2024.1.0         | 121.0 MB  | :  22% 0.2242527718128855/1 [00:00<00:02,  3.37s/it]
#
#
# llvm-openmp-18.1.4   | 57.5 MB   | :  47% 0.4684727692246489/1 [00:00<00:00,  1.65s/it]
#
#
#
# pytorch-1.12.0       | 1.19 GB   | :   2% 0.02111839375078694/1 [00:00<00:33, 34.29s/it]
# cudatoolkit-11.3.1   | 603.5 MB  | :   4% 0.04499560948446923/1 [00:00<00:15, 16.50s/it]
#
# mkl-2024.1.0         | 121.0 MB  | :  26% 0.2551262812963415/1 [00:00<00:02,  3.33s/it]
#
#
# llvm-openmp-18.1.4   | 57.5 MB   | :  54% 0.5363673734601053/1 [00:01<00:00,  1.66s/it]
#
#
#
# pytorch-1.12.0       | 1.19 GB   | :   2% 0.024442111895583915/1 [00:01<00:32, 33.09s/it]
# cudatoolkit-11.3.1   | 603.5 MB  | :   5% 0.051234931628172956/1 [00:01<00:16, 17.25s/it]
#
# mkl-2024.1.0         | 121.0 MB  | :  30% 0.29568813057586113/1 [00:01<00:02,  3.01s/it]
#
#
#
# pillow-9.4.0         | 44.3 MB   | :  75% 0.7472776796073674/1 [00:01<00:00,  1.27s/it]
#
#
# pytorch-1.12.0       | 1.19 GB   | :   3% 0.028226037168122012/1 [00:01<00:29, 30.77s/it]
# cudatoolkit-11.3.1   | 603.5 MB  | :   6% 0.057163582129866546/1 [00:01<00:16, 17.82s/it]
#
# mkl-2024.1.0         | 121.0 MB  | :  33% 0.33147039888932267/1 [00:01<00:01,  2.95s/it]
#
#
#
# pillow-9.4.0         | 44.3 MB   | :  85% 0.8474319320889588/1 [00:01<00:00,  1.19s/it]
#
#
# pytorch-1.12.0       | 1.19 GB   | :   3% 0.031524188250266705/1 [00:01<00:31, 32.48s/it]
# cudatoolkit-11.3.1   | 603.5 MB  | :   6% 0.06316990054206266/1 [00:01<00:16, 17.48s/it]
#
# mkl-2024.1.0         | 121.0 MB  | :  37% 0.36570253283541404/1 [00:01<00:01,  3.04s/it]
#
#
#
# pillow-9.4.0         | 44.3 MB   | :  94% 0.9430016589287873/1 [00:01<00:00,  1.14s/it]
#
#
# llvm-openmp-18.1.4   | 57.5 MB   | :  76% 0.7612343026879368/1 [00:01<00:00,  1.48s/it]
# pytorch-1.12.0       | 1.19 GB   | :   3% 0.034656153425171546/1 [00:01<00:34, 35.26s/it]
#
# mkl-2024.1.0         | 121.0 MB  | :  40% 0.3989012438699253/1 [00:01<00:01,  3.07s/it]
#
#
# llvm-openmp-18.1.4   | 57.5 MB   | :  83% 0.829400485340335/1 [00:01<00:00,  1.57s/it]
# pytorch-1.12.0       | 1.19 GB   | :   4% 0.039040904670038325/1 [00:01<00:30, 31.57s/it]
#
# mkl-2024.1.0         | 121.0 MB  | :  44% 0.4353294015031245/1 [00:01<00:01,  2.97s/it]
#
#
# llvm-openmp-18.1.4   | 57.5 MB   | :  90% 0.9002824521621514/1 [00:01<00:00,  1.52s/it]
# pytorch-1.12.0       | 1.19 GB   | :   4% 0.04340008885225282/1 [00:01<00:27, 28.61s/it]
#
# mkl-2024.1.0         | 121.0 MB  | :  48% 0.4775705630139618/1 [00:01<00:01,  2.78s/it]
#
#
# llvm-openmp-18.1.4   | 57.5 MB   | :  98% 0.9757812520719789/1 [00:01<00:00,  1.46s/it]
# pytorch-1.12.0       | 1.19 GB   | :   5% 0.04759308712722747/1 [00:01<00:25, 27.13s/it]
#
# mkl-2024.1.0         | 121.0 MB  | :  52% 0.5199409023887466/1 [00:01<00:01,  2.66s/it]
# pytorch-1.12.0       | 1.19 GB   | :   5% 0.05135144533711328/1 [00:01<00:26, 28.06s/it]
#
# mkl-2024.1.0         | 121.0 MB  | :  56% 0.5642489097227441/1 [00:01<00:01,  2.52s/it]
# pytorch-1.12.0       | 1.19 GB   | :   6% 0.05522485532893437/1 [00:01<00:25, 27.41s/it]
#
# mkl-2024.1.0         | 121.0 MB  | :  61% 0.6139823873425373/1 [00:01<00:00,  2.37s/it]
# pytorch-1.12.0       | 1.19 GB   | :   6% 0.05891929588218947/1 [00:02<00:25, 27.40s/it]
#
# pytorch-1.12.0       | 1.19 GB   | :   6% 0.062652087029423/1 [00:02<00:25, 27.28s/it]
# cudatoolkit-11.3.1   | 603.5 MB  | :  13% 0.13074098267926904/1 [00:02<00:11, 12.82s/it]
#
# pytorch-1.12.0       | 1.19 GB   | :   7% 0.06675560058511465/1 [00:02<00:25, 27.53s/it]
# cudatoolkit-11.3.1   | 603.5 MB  | :  14% 0.13884433467503363/1 [00:02<00:11, 13.29s/it]
#
# pytorch-1.12.0       | 1.19 GB   | :   7% 0.07041169054439132/1 [00:02<00:27, 29.69s/it]
# cudatoolkit-11.3.1   | 603.5 MB  | :  15% 0.14640401129728048/1 [00:02<00:12, 14.17s/it]
#
# pytorch-1.12.0       | 1.19 GB   | :   7% 0.0738248934084713/1 [00:02<00:27, 30.04s/it]
# cudatoolkit-11.3.1   | 603.5 MB  | :  15% 0.15352356976001294/1 [00:02<00:12, 15.09s/it]
#
# pytorch-1.12.0       | 1.19 GB   | :   8% 0.0771869621472467/1 [00:02<00:27, 30.10s/it]
# cudatoolkit-11.3.1   | 603.5 MB  | :  16% 0.1602288993667319/1 [00:02<00:12, 15.21s/it]
#
#
#
#
# torchvision-0.13.0   | 28.3 MB   | :   0% 0.0005518938542119027/1 [00:02<1:17:44, 4667.48s/it]
#
# pytorch-1.12.0       | 1.19 GB   | :   8% 0.08053624735469596/1 [00:02<00:29, 31.60s/it]
#
#
#
#
# torchvision-0.13.0   | 28.3 MB   | :  13% 0.13190263115664475/1 [00:02<00:12, 14.48s/it]
#
# mkl-2024.1.0         | 121.0 MB  | :  90% 0.9043742254965503/1 [00:02<00:00,  2.94s/it]
# pytorch-1.12.0       | 1.19 GB   | :   8% 0.08373213018623152/1 [00:02<00:29, 31.79s/it]
#
#
#
#
#
# ffmpeg-4.3           | 9.9 MB    | :   0% 0.0015713236502815128/1 [00:02<29:20, 1763.37s/it]
#
# mkl-2024.1.0         | 121.0 MB  | :  94% 0.9389938930344842/1 [00:02<00:00,  3.02s/it]
#
#
#
#
# torchvision-0.13.0   | 28.3 MB   | :  21% 0.2058564076210397/1 [00:02<00:07,  8.91s/it]
# cudatoolkit-11.3.1   | 603.5 MB  | :  17% 0.17283699017164358/1 [00:02<00:15, 18.45s/it]
#
#
#
#
#
# ffmpeg-4.3           | 9.9 MB    | :  26% 0.2639823732472942/1 [00:02<00:05,  7.74s/it]
#
#
#
#
# pytorch-1.12.0       | 1.19 GB   | :   9% 0.08690244595511479/1 [00:02<00:34, 37.92s/it]
#
#
#
#
#
# ffmpeg-4.3           | 9.9 MB    | :  49% 0.49182430253811354/1 [00:02<00:01,  3.71s/it]
# cudatoolkit-11.3.1   | 603.5 MB  | :  18% 0.17840319042432534/1 [00:02<00:16, 20.01s/it]
#
# pytorch-1.12.0       | 1.19 GB   | :   9% 0.08968925578421379/1 [00:03<00:34, 38.13s/it]
#
#
#
#
# torchvision-0.13.0   | 28.3 MB   | :  34% 0.3432779773198035/1 [00:03<00:03,  4.74s/it]
#
#
#
#
#
# ffmpeg-4.3           | 9.9 MB    | :  86% 0.8626566840045505/1 [00:03<00:00,  1.78s/it]
# pytorch-1.12.0       | 1.19 GB   | :   9% 0.09241214795668208/1 [00:03<00:35, 39.16s/it]
#
#
#
#
# torchvision-0.13.0   | 28.3 MB   | :  45% 0.4492415973284888/1 [00:03<00:01,  3.23s/it]
# pytorch-1.12.0       | 1.19 GB   | :  10% 0.09503277187854123/1 [00:03<00:35, 39.70s/it]
# pytorch-1.12.0       | 1.19 GB   | :  10% 0.0990212336522976/1 [00:03<00:31, 34.56s/it]
# cudatoolkit-11.3.1   | 603.5 MB  | :  20% 0.2008751058630591/1 [00:03<00:15, 18.85s/it]
#
#
#
#
# pytorch-1.12.0       | 1.19 GB   | :  10% 0.1019870129199626/1 [00:03<00:31, 34.90s/it]
#
#
#
#
#
#
# numpy-2.0.0          | 7.4 MB    | :   0% 0.00210654510145977/1 [00:03<27:45, 1668.52s/it]
#
#
#
#
# torchvision-0.13.0   | 28.3 MB   | :  61% 0.6103946027583644/1 [00:03<00:00,  2.50s/it]
# pytorch-1.12.0       | 1.19 GB   | :  10% 0.10490165806232302/1 [00:03<00:34, 38.18s/it]
#
#
#
#
#
#
# numpy-2.0.0          | 7.4 MB    | :  38% 0.3770715731612988/1 [00:03<00:04,  6.81s/it]
#
#
#
#
# torchvision-0.13.0   | 28.3 MB   | :  69% 0.6937305747443617/1 [00:03<00:00,  2.10s/it]
# cudatoolkit-11.3.1   | 603.5 MB  | :  21% 0.21133438447740063/1 [00:03<00:15, 20.16s/it]
#
#
#
#
#
#
# pytorch-1.12.0       | 1.19 GB   | :  11% 0.10758619964081288/1 [00:03<00:35, 39.82s/it]
#
#
#
#
# torchvision-0.13.0   | 28.3 MB   | :  77% 0.7704438204798162/1 [00:03<00:00,  1.86s/it]
# pytorch-1.12.0       | 1.19 GB   | :  11% 0.11014290590604132/1 [00:03<00:35, 39.69s/it]
#
#
#
#
# torchvision-0.13.0   | 28.3 MB   | :  88% 0.8769593343427134/1 [00:03<00:00,  1.54s/it]
# pytorch-1.12.0       | 1.19 GB   | :  11% 0.11276352982790049/1 [00:03<00:34, 39.26s/it]
#
#
#
#
# torchvision-0.13.0   | 28.3 MB   | :  98% 0.9801634850803392/1 [00:03<00:00,  1.36s/it]
# pytorch-1.12.0       | 1.19 GB   | :  12% 0.11534580315578122/1 [00:04<00:35, 40.56s/it]
# cudatoolkit-11.3.1   | 603.5 MB  | :  23% 0.23367685339863017/1 [00:04<00:14, 18.37s/it]
#
#
#
#
#
#
#
# pytorch-1.12.0       | 1.19 GB   | :  12% 0.1194876673054513/1 [00:04<00:30, 34.16s/it]
# cudatoolkit-11.3.1   | 603.5 MB  | :  24% 0.2405892974333559/1 [00:04<00:12, 17.05s/it]
#
#
#
#
#
#
#
# pytorch-1.12.0       | 1.19 GB   | :  12% 0.12246623010444242/1 [00:04<00:31, 35.74s/it]
#
#
#
#
#
#
#
# nettle-3.6           | 6.5 MB    | :  70% 0.6966488279224575/1 [00:04<00:01,  3.69s/it]
# pytorch-1.12.0       | 1.19 GB   | :  13% 0.125304174058846/1 [00:04<00:33, 38.35s/it]
# pytorch-1.12.0       | 1.19 GB   | :  13% 0.12812933448192343/1 [00:04<00:32, 37.58s/it]
# cudatoolkit-11.3.1   | 603.5 MB  | :  26% 0.25884125640145184/1 [00:04<00:12, 17.44s/it]
#
#
#
#
#
#
#
#
# pytorch-1.12.0       | 1.19 GB   | :  13% 0.13106954668693613/1 [00:04<00:31, 36.51s/it]
# pytorch-1.12.0       | 1.19 GB   | :  13% 0.13392027417266586/1 [00:04<00:31, 36.17s/it]
# cudatoolkit-11.3.1   | 603.5 MB  | :  27% 0.2701289927278204/1 [00:04<00:13, 18.61s/it]
#
#
#
#
#
#
#
#
#
# pytorch-1.12.0       | 1.19 GB   | :  14% 0.1372056417234844/1 [00:04<00:29, 34.30s/it]
#
#
#
#
#
#
#
#
#
#
# openh264-2.1.1       | 1.5 MB    | :   1% 0.01033460034793491/1 [00:04<07:39, 464.52s/it]
# pytorch-1.12.0       | 1.19 GB   | :  14% 0.14018420452247554/1 [00:04<00:29, 34.11s/it]
# cudatoolkit-11.3.1   | 603.5 MB  | :  28% 0.2832807589062499/1 [00:04<00:12, 16.89s/it]
#
#
#
#
#
#
#
#
#
#
#
# libgfortran5-13.2.0  | 1.4 MB    | :   1% 0.01116697019596724/1 [00:04<07:18, 443.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.12.0       | 1.19 GB   | :  14% 0.14382751095042606/1 [00:04<00:27, 31.88s/it]
# pytorch-1.12.0       | 1.19 GB   | :  15% 0.1469850431879832/1 [00:05<00:28, 33.39s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lame-3.100           | 496 KB    | :   3% 0.032235596881898566/1 [00:05<02:34, 159.33s/it]
# cudatoolkit-11.3.1   | 603.5 MB  | :  30% 0.29521572782013955/1 [00:05<00:11, 16.98s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.12.1      | 620 KB    | :   3% 0.025802712560553852/1 [00:05<03:16, 201.58s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.12.0       | 1.19 GB   | :  15% 0.1500147401122789/1 [00:05<00:30, 36.19s/it]
# cudatoolkit-11.3.1   | 603.5 MB  | :  30% 0.30114437832183316/1 [00:05<00:12, 17.28s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.5.0        | 397 KB    | :   4% 0.040289680441652015/1 [00:05<02:06, 131.31s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.12.0       | 1.19 GB   | :  15% 0.15295495231729161/1 [00:05<00:30, 35.75s/it]
# cudatoolkit-11.3.1   | 603.5 MB  | :  31% 0.30720247534103096/1 [00:05<00:11, 17.05s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.12.0       | 1.19 GB   | :  16% 0.15647042343198073/1 [00:05<00:28, 33.37s/it]
# pytorch-1.12.0       | 1.19 GB   | :  16% 0.15951290388760256/1 [00:05<00:29, 34.77s/it]
# pytorch-1.12.0       | 1.19 GB   | :  16% 0.16275992084444268/1 [00:05<00:28, 33.80s/it]
# pytorch-1.12.0       | 1.19 GB   | :  17% 0.16599415426995667/1 [00:05<00:27, 33.11s/it]
# pytorch-1.12.0       | 1.19 GB   | :  17% 0.16953519244729806/1 [00:05<00:26, 31.55s/it]
# pytorch-1.12.0       | 1.19 GB   | :  17% 0.173753757784925/1 [00:05<00:23, 28.78s/it]
# pytorch-1.12.0       | 1.19 GB   | :  18% 0.17913562447323086/1 [00:06<00:20, 25.38s/it]
# pytorch-1.12.0       | 1.19 GB   | :  18% 0.1830857356530088/1 [00:06<00:21, 26.28s/it]
# pytorch-1.12.0       | 1.19 GB   | :  19% 0.1869591456448299/1 [00:06<00:21, 26.24s/it]
# pytorch-1.12.0       | 1.19 GB   | :  19% 0.19170183576682867/1 [00:06<00:19, 24.50s/it]
# pytorch-1.12.0       | 1.19 GB   | :  20% 0.1958053493225203/1 [00:06<00:20, 25.43s/it]
# pytorch-1.12.0       | 1.19 GB   | :  20% 0.20035628647462694/1 [00:06<00:19, 24.46s/it]
# pytorch-1.12.0       | 1.19 GB   | :  20% 0.20489444009540744/1 [00:06<00:18, 23.83s/it]
# pytorch-1.12.0       | 1.19 GB   | :  21% 0.20968826434271076/1 [00:06<00:18, 22.94s/it]
# pytorch-1.12.0       | 1.19 GB   | :  21% 0.21439260387073109/1 [00:06<00:17, 22.43s/it]
#
#
#
# pillow-9.4.0         | 44.3 MB   | : 100% 1.0/1 [00:06<00:00,  1.14s/it]
# pytorch-1.12.0       | 1.19 GB   | :  22% 0.21886683983488087/1 [00:07<00:17, 23.02s/it]
# pytorch-1.12.0       | 1.19 GB   | :  22% 0.22322602401709538/1 [00:07<00:19, 24.91s/it]
# pytorch-1.12.0       | 1.19 GB   | :  23% 0.22730397051013473/1 [00:08<01:17, 100.82s/it]
# pytorch-1.12.0       | 1.19 GB   | :  23% 0.2319571759128505/1 [00:08<00:58, 76.30s/it]
# pytorch-1.12.0       | 1.19 GB   | :  24% 0.23685326841076298/1 [00:08<00:44, 58.88s/it]
# pytorch-1.12.0       | 1.19 GB   | :  24% 0.24059884308932264/1 [00:08<00:38, 51.00s/it]
# pytorch-1.12.0       | 1.19 GB   | :  24% 0.24477905783297116/1 [00:08<00:32, 43.23s/it]
# pytorch-1.12.0       | 1.19 GB   | :  25% 0.24950896442364376/1 [00:08<00:27, 36.59s/it]
# pytorch-1.12.0       | 1.19 GB   | :  25% 0.2534974261974001/1 [00:09<00:26, 35.53s/it]
# pytorch-1.12.0       | 1.19 GB   | :  26% 0.25723021734463364/1 [00:09<00:24, 33.27s/it]
# pytorch-1.12.0       | 1.19 GB   | :  26% 0.26093744142921493/1 [00:09<00:23, 32.05s/it]
# pytorch-1.12.0       | 1.19 GB   | :  27% 0.2655395127066261/1 [00:09<00:21, 29.31s/it]
# pytorch-1.12.0       | 1.19 GB   | :  27% 0.26997539807679743/1 [00:09<00:20, 28.24s/it]
# pytorch-1.12.0       | 1.19 GB   | :  27% 0.27402777750718454/1 [00:09<00:19, 27.35s/it]
# pytorch-1.12.0       | 1.19 GB   | :  28% 0.2827333623402874/1 [00:09<00:18, 25.18s/it]
# pytorch-1.12.0       | 1.19 GB   | :  29% 0.28683687589597906/1 [00:09<00:18, 25.29s/it]
# pytorch-1.12.0       | 1.19 GB   | :  29% 0.2908892553263661/1 [00:09<00:17, 25.29s/it]
# pytorch-1.12.0       | 1.19 GB   | :  29% 0.2949160676941009/1 [00:10<00:18, 26.09s/it]
# pytorch-1.12.0       | 1.19 GB   | :  30% 0.2988022612172481/1 [00:10<00:18, 26.48s/it]
#
#
# llvm-openmp-18.1.4   | 57.5 MB   | : 100% 1.0/1 [00:10<00:00,  1.46s/it]
# pytorch-1.12.0       | 1.19 GB   | :  30% 0.3026245370837647/1 [00:10<00:18, 26.70s/it]
# pytorch-1.12.0       | 1.19 GB   | :  31% 0.30666413298282563/1 [00:10<00:18, 26.16s/it]
# pytorch-1.12.0       | 1.19 GB   | :  31% 0.31278744448804774/1 [00:10<00:15, 22.27s/it]
# cudatoolkit-11.3.1   | 603.5 MB  | :  62% 0.6165019842656304/1 [00:10<00:05, 14.28s/it]
# pytorch-1.12.0       | 1.19 GB   | :  32% 0.3173255981088282/1 [00:10<00:16, 24.46s/it]
# pytorch-1.12.0       | 1.19 GB   | :  32% 0.3215058128524767/1 [00:10<00:18, 26.64s/it]
# pytorch-1.12.0       | 1.19 GB   | :  33% 0.32724561841791455/1 [00:10<00:15, 23.38s/it]
# pytorch-1.12.0       | 1.19 GB   | :  33% 0.33225676269776233/1 [00:10<00:14, 22.33s/it]
# pytorch-1.12.0       | 1.19 GB   | :  34% 0.3370633704763918/1 [00:11<00:14, 21.89s/it]
# pytorch-1.12.0       | 1.19 GB   | :  34% 0.34194667944297813/1 [00:11<00:14, 21.47s/it]
# pytorch-1.12.0       | 1.19 GB   | :  35% 0.34703452491078274/1 [00:11<00:13, 20.98s/it]
# pytorch-1.12.0       | 1.19 GB   | :  35% 0.35185391622073836/1 [00:11<00:14, 22.93s/it]
# pytorch-1.12.0       | 1.19 GB   | :  36% 0.3569034110945645/1 [00:11<00:14, 21.97s/it]
# pytorch-1.12.0       | 1.19 GB   | :  36% 0.36241311309613183/1 [00:11<00:13, 20.74s/it]
# pytorch-1.12.0       | 1.19 GB   | :  37% 0.3675648762205671/1 [00:11<00:12, 20.34s/it]
# pytorch-1.12.0       | 1.19 GB   | :  38% 0.3795174780105101/1 [00:11<00:11, 18.36s/it]
# pytorch-1.12.0       | 1.19 GB   | :  39% 0.38525728357594796/1 [00:11<00:11, 18.14s/it]
# pytorch-1.12.0       | 1.19 GB   | :  39% 0.39080533617149366/1 [00:12<00:11, 19.60s/it]
# cudatoolkit-11.3.1   | 603.5 MB  | :  76% 0.7565890055087047/1 [00:12<00:03, 12.44s/it]
# pytorch-1.12.0       | 1.19 GB   | :  40% 0.3959954498899074/1 [00:12<00:15, 26.30s/it]
# pytorch-1.12.0       | 1.19 GB   | :  40% 0.4011344294830166/1 [00:12<00:14, 24.35s/it]
# cudatoolkit-11.3.1   | 603.5 MB  | :  79% 0.7867500440871895/1 [00:12<00:02, 11.21s/it]
# pytorch-1.12.0       | 1.19 GB   | :  41% 0.4057109336977755/1 [00:12<00:16, 27.34s/it]
# pytorch-1.12.0       | 1.19 GB   | :  41% 0.40975052959683644/1 [00:12<00:19, 33.46s/it]
# cudatoolkit-11.3.1   | 603.5 MB  | :  82% 0.8162120714711515/1 [00:12<00:02, 11.39s/it]
#
#
#
#
#
#
# numpy-2.0.0          | 7.4 MB    | : 100% 1.0/1 [00:12<00:00, 14.81s/it]
#
#
#
#
#
#
# numpy-2.0.0          | 7.4 MB    | : 100% 1.0/1 [00:12<00:00, 14.81s/it]
# pytorch-1.12.0       | 1.19 GB   | :  41% 0.4131637324609164/1 [00:12<00:21, 36.22s/it]
# pytorch-1.12.0       | 1.19 GB   | :  42% 0.4162189964478644/1 [00:13<00:21, 36.63s/it]
#
#
#
#
#
# ffmpeg-4.3           | 9.9 MB    | : 100% 1.0/1 [00:13<00:00,  1.78s/it]
# pytorch-1.12.0       | 1.19 GB   | :  42% 0.419146425121551/1 [00:13<00:21, 36.74s/it]
# pytorch-1.12.0       | 1.19 GB   | :  42% 0.4220099361386068/1 [00:13<00:21, 36.81s/it]
# cudatoolkit-11.3.1   | 603.5 MB  | :  88% 0.8831359210208367/1 [00:13<00:01,  9.71s/it]
# pytorch-1.12.0       | 1.19 GB   | :  42% 0.4248223130303581/1 [00:13<00:29, 50.78s/it]
# pytorch-1.12.0       | 1.19 GB   | :  43% 0.4302425303126424/1 [00:13<00:21, 37.29s/it]
# pytorch-1.12.0       | 1.19 GB   | :  44% 0.43653202772510435/1 [00:13<00:20, 36.89s/it]
# cudatoolkit-11.3.1   | 603.5 MB  | :  93% 0.9346815242910198/1 [00:13<00:00, 10.49s/it]
# pytorch-1.12.0       | 1.19 GB   | :  44% 0.43952337405542163/1 [00:14<00:25, 44.96s/it]
# pytorch-1.12.0       | 1.19 GB   | :  44% 0.4441254453328329/1 [00:14<00:20, 36.36s/it]
# cudatoolkit-11.3.1   | 603.5 MB  | :  97% 0.9741886014333099/1 [00:14<00:00,  8.88s/it]
# pytorch-1.12.0       | 1.19 GB   | :  45% 0.44729576110171615/1 [00:14<00:21, 39.24s/it]
# pytorch-1.12.0       | 1.19 GB   | :  45% 0.45019762271275043/1 [00:14<00:20, 38.06s/it]
#
#
#
#
#
#
#
# nettle-3.6           | 6.5 MB    | : 100% 1.0/1 [00:15<00:00, 17.14s/it]
#
#
#
#
#
#
#
# nettle-3.6           | 6.5 MB    | : 100% 1.0/1 [00:15<00:00, 17.14s/it]
#
#
#
#
#
#
#
#
# libhwloc-2.9.3       | 2.5 MB    | : 100% 1.0/1 [00:15<00:00, 14.24s/it]
#
#
#
#
#
#
#
#
# libhwloc-2.9.3       | 2.5 MB    | : 100% 1.0/1 [00:15<00:00, 14.24s/it]
#
#
#
#
#
#
#
#
#
#
# openh264-2.1.1       | 1.5 MB    | : 100% 1.0/1 [00:16<00:00, 14.65s/it]
#
#
#
#
#
#
#
#
#
#
# openh264-2.1.1       | 1.5 MB    | : 100% 1.0/1 [00:16<00:00, 14.65s/it]
#
#
#
#
#
#
#
#
#
# gnutls-3.6.13        | 2.0 MB    | : 100% 1.0/1 [00:17<00:00, 16.03s/it]
#
#
#
#
#
#
#
#
#
# gnutls-3.6.13        | 2.0 MB    | : 100% 1.0/1 [00:17<00:00, 16.03s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-include-2024.1.0 | 673 KB    | : 100% 1.0/1 [00:17<00:00, 16.27s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-include-2024.1.0 | 673 KB    | : 100% 1.0/1 [00:17<00:00, 16.27s/it]
#
#
#
#
#
#
#
#
#
#
#
# libgfortran5-13.2.0  | 1.4 MB    | : 100% 1.0/1 [00:17<00:00, 16.38s/it]
#
#
#
#
#
#
#
#
#
#
#
# libgfortran5-13.2.0  | 1.4 MB    | : 100% 1.0/1 [00:17<00:00, 16.38s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lame-3.100           | 496 KB    | : 100% 1.0/1 [00:18<00:00, 16.67s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lame-3.100           | 496 KB    | : 100% 1.0/1 [00:18<00:00, 16.67s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gmp-6.3.0            | 449 KB    | : 100% 1.0/1 [00:18<00:00, 16.70s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gmp-6.3.0            | 449 KB    | : 100% 1.0/1 [00:18<00:00, 16.70s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.12.1      | 620 KB    | : 100% 1.0/1 [00:18<00:00, 16.75s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.12.1      | 620 KB    | : 100% 1.0/1 [00:18<00:00, 16.75s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.5.0        | 397 KB    | : 100% 1.0/1 [00:18<00:00, 16.86s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.5.0        | 397 KB    | : 100% 1.0/1 [00:18<00:00, 16.86s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libwebp-base-1.4.0   | 429 KB    | : 100% 1.0/1 [00:18<00:00, 16.90s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libwebp-base-1.4.0   | 429 KB    | : 100% 1.0/1 [00:18<00:00, 16.90s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
# torchvision-0.13.0   | 28.3 MB   | : 100% 1.0/1 [00:20<00:00,  1.36s/it]
#
# mkl-2024.1.0         | 121.0 MB  | : 100% 1.0/1 [00:25<00:00,  3.57s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ('Connection broken: IncompleteRead(582398877 bytes read, 699250112 more expected)', IncompleteRead(582398877 bytes read, 699250112 more expected))
# ('Connection broken: IncompleteRead(582398877 bytes read, 699250112 more expected)', IncompleteRead(582398877 bytes read, 699250112 more expected))
#
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
import sys
sys.path.append("./robotic_grasping//src")
# !python -m utils.dataset_processing.generate_cornell_depth ./
# Out:
# /usr/local/bin/python: Error while finding module specification for 'utils.dataset_processing.generate_cornell_depth' (ModuleNotFoundError: No module named 'utils')
